# %%
import pandas as pd
import numpy as np

from pandas import Series, DataFrame

# %%
df = pd.read_excel("../Week4/excel-comp-data.xlsx")
df
# Out:
#     account                              name  \
# 0    211829        Kerluke, Koepp and Hilpert
# 1    320563                    Walter-Trantow
# 2    648336        Bashirian, Kunde and Price
# 3    109996       D'Amore, Gleichner and Bode
# 4    121213                     Bauch-Goldner
# 5    132971  Williamson, Schumm and Hettinger
# 6    145068                        Casper LLC
# 7    205217                  Kovacek-Johnston
# 8    209744                    Champlin-Morar
# 9    212303                    Gerhold-Maggio
# 10   214098       Goodwin, Homenick and Jerde
# 11   231907                        Hahn-Moore
# 12   242368      Frami, Anderson and Donnelly
# 13   268755                       Walsh-Haley
# 14   273274                     McDermott PLC
#
#                                   street               city          state  \
# 0                     34456 Sean Highway         New Jaycob          Texas
# ...

# %%
df.keys()
# Out:
# Index(['account', 'name', 'street', 'city', 'state', 'postal-code', 'Jan',
#        'Feb', 'Mar'],
#       dtype='object')

# %%
df.loc[[0,2],["name","street"]]
# Out:
#                          name                                street
# 0  Kerluke, Koepp and Hilpert                    34456 Sean Highway
# 2  Bashirian, Kunde and Price  62184 Schamberger Underpass Apt. 231

# %%
df.index = df['account'] # account 값을 index로 사용
df.head()
# Out:
#          account                         name  \
# account
# 211829    211829   Kerluke, Koepp and Hilpert
# 320563    320563               Walter-Trantow
# 648336    648336   Bashirian, Kunde and Price
# 109996    109996  D'Amore, Gleichner and Bode
# 121213    121213                Bauch-Goldner
#
#                                        street             city          state  \
# account
# 211829                     34456 Sean Highway       New Jaycob          Texas
# 320563                      1311 Alvis Tunnel    Port Khadijah  NorthCarolina
# 648336   62184 Schamberger Underpass Apt. 231   New Lilianland           Iowa
# 109996            155 Fadel Crescent Apt. 144       Hyattburgh          Maine
# 121213                    7274 Marissa Common  Shanahanchester     California
#
#          postal-code     Jan     Feb    Mar
# account
# 211829         28752   10000   62000  35000
# 320563         38365   95000   45000  35000
# 648336         76517   91000  120000  35000
# ...

# %%
df_sort = df.sort_index()
df_sort.head(5)
# Out:
#          account                              name  \
# account
# 109996    109996       D'Amore, Gleichner and Bode
# 121213    121213                     Bauch-Goldner
# 132971    132971  Williamson, Schumm and Hettinger
# 145068    145068                        Casper LLC
# 205217    205217                  Kovacek-Johnston
#
#                                street               city        state  \
# account
# 109996    155 Fadel Crescent Apt. 144         Hyattburgh        Maine
# 121213            7274 Marissa Common    Shanahanchester   California
# 132971           89403 Casimer Spring       Jeremieburgh     Arkansas
# 145068   340 Consuela Bridge Apt. 400  Lake Gabriellaton   Mississipi
# 205217   91971 Cronin Vista Suite 601         Deronville  RhodeIsland
#
#          postal-code     Jan     Feb    Mar
# account
# 109996         46021   45000  120000  10000
# 121213         49681  162000  120000  35000
# 132971         62785  150000  120000  35000
# ...

# %%
df_sort_city = df.sort_values(by='city')
df_sort_city.head(5)
# Out:
#          account                              name  \
# account
# 205217    205217                  Kovacek-Johnston
# 242368    242368      Frami, Anderson and Donnelly
# 268755    268755                       Walsh-Haley
# 109996    109996       D'Amore, Gleichner and Bode
# 132971    132971  Williamson, Schumm and Hettinger
#
#                                street          city        state  postal-code  \
# account
# 205217   91971 Cronin Vista Suite 601    Deronville  RhodeIsland        53461
# 242368                182 Bertie Road   East Davian         Iowa        72686
# 268755           2624 Beatty Parkways  Goodwinmouth  RhodeIsland        31919
# 109996    155 Fadel Crescent Apt. 144    Hyattburgh        Maine        46021
# 132971           89403 Casimer Spring  Jeremieburgh     Arkansas        62785
#
#             Jan     Feb    Mar
# account
# 205217   145000   95000  35000
# 242368   162000  120000  35000
# 268755    55000  120000  35000
# ...

# %%
df.drop(205217, inplace=True)

# %%
df
# Out:
#          account                              name  \
# account
# 211829    211829        Kerluke, Koepp and Hilpert
# 320563    320563                    Walter-Trantow
# 648336    648336        Bashirian, Kunde and Price
# 109996    109996       D'Amore, Gleichner and Bode
# 121213    121213                     Bauch-Goldner
# 132971    132971  Williamson, Schumm and Hettinger
# 145068    145068                        Casper LLC
# 209744    209744                    Champlin-Morar
# 212303    212303                    Gerhold-Maggio
# 214098    214098       Goodwin, Homenick and Jerde
# 231907    231907                        Hahn-Moore
# 242368    242368      Frami, Anderson and Donnelly
# 268755    268755                       Walsh-Haley
# 273274    273274                     McDermott PLC
#
#                                        street               city  \
# account
# 211829                     34456 Sean Highway         New Jaycob
# ...

# %%
print(df.keys())
# Out:
# Index(['account', 'name', 'street', 'city', 'state', 'postal-code', 'Jan',
#        'Feb', 'Mar'],
#       dtype='object')

# %%
df.drop('city', axis=1, inplace=True)
print(df.keys())
# Out:
# Index(['account', 'name', 'street', 'state', 'postal-code', 'Jan', 'Feb',
#        'Mar'],
#       dtype='object')

# %%
grouped = df.groupby('Mar')
grouped.get_group(35000)
# Out:
#          account                              name  \
# account
# 211829    211829        Kerluke, Koepp and Hilpert
# 320563    320563                    Walter-Trantow
# 648336    648336        Bashirian, Kunde and Price
# 121213    121213                     Bauch-Goldner
# 132971    132971  Williamson, Schumm and Hettinger
# 209744    209744                    Champlin-Morar
# 212303    212303                    Gerhold-Maggio
# 242368    242368      Frami, Anderson and Donnelly
# 268755    268755                       Walsh-Haley
#
#                                        street          state  postal-code  \
# account
# 211829                     34456 Sean Highway          Texas        28752
# 320563                      1311 Alvis Tunnel  NorthCarolina        38365
# 648336   62184 Schamberger Underpass Apt. 231           Iowa        76517
# 121213                    7274 Marissa Common     California        49681
# ...

# %%
ipl_data = {'Team': ['Riders', 'Riders', 'Devils', 'Devils', 'Kings', 'kings', 'Kings', 'Kings', 'Riders', 'Royals', 'Royals', 'Riders'],
            'Rank': [1, 2, 2, 3, 3,4 ,1 ,1,2 , 4,1,2],
            'Year': [2014,2015,2014,2014,2014,2015,2016,2017,2016,2014,2015,2017],
            'Points':[876,789,863,673,741,812,756,788,694,701,804,690]}
df = pd.DataFrame(ipl_data)
df
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 2   Devils     2  2014     863
# 3   Devils     3  2014     673
# 4    Kings     3  2014     741
# 5    kings     4  2015     812
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 9   Royals     4  2014     701
# 10  Royals     1  2015     804
# 11  Riders     2  2017     690

# %%
df.groupby('Team').filter(lambda x: len(x) >= 3)
# Out:
#       Team  Rank  Year  Points
# 0   Riders     1  2014     876
# 1   Riders     2  2015     789
# 4    Kings     3  2014     741
# 6    Kings     1  2016     756
# 7    Kings     1  2017     788
# 8   Riders     2  2016     694
# 11  Riders     2  2017     690
